# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm as mplcm
import matplotlib.colors as colors
from einops import rearrange
from PIL import Image
#f tqdm
import json
import time
from pathlib import Path
from sklearn import linear_model
import mediapy as media

# %%
# !ls -lt baselines
# Out:
# total 1012
# -rw-r--r-- 1 bartek bartek 817492 10-20 20:50 Visualizations_over_time.ipynb
# drwxr-xr-x 5 bartek bartek  12288 10-20 20:42 session_5db1f749
# -rw-r--r-- 1 bartek bartek   4023 10-19 21:57 run_baseline_parallel.py
# drwxr-xr-x 3 bartek bartek   4096 10-19 21:57 session_36c3ad63
# drwxr-xr-x 2 bartek bartek   4096 10-19 21:57 __pycache__
# -rw-r--r-- 1 bartek bartek   2331 10-19 21:57 custom_networks.py
# drwxr-xr-x 3 bartek bartek   4096 10-19 21:56 session_6e939471
# drwxr-xr-x 3 bartek bartek   4096 10-19 21:56 session_6a385e28
# drwxr-xr-x 4 bartek bartek   4096 10-19 21:54 session_861f065e
# drwxr-xr-x 3 bartek bartek   4096 10-19 21:42 session_2de0e7d6
# drwxr-xr-x 4 bartek bartek   4096 10-19 21:37 session_0db56652
# -rw-r--r-- 1 bartek bartek  22449 10-19 21:21 red_gym_env.py
# drwxr-xr-x 3 bartek bartek   4096 10-19 00:32 session_1297937d
# drwxr-xr-x 3 bartek bartek   4096 10-19 00:31 session_b5b0f04d
# drwxr-xr-x 3 bartek bartek   4096 10-19 00:30 session_d2227cc1
# drwxr-xr-x 3 bartek bartek   4096 10-19 00:19 session_0216d694
# drwxr-xr-x 3 bartek bartek   4096 10-19 00:18 session_bfd8796d
# drwxr-xr-x 3 bartek bartek   4096 10-19 00:17 session_cb731afc
# drwxr-xr-x 3 bartek bartek   4096 10-19 00:16 session_d158c272
# drwxr-xr-x 3 bartek bartek   4096 10-19 00:14 session_37459227
# drwxr-xr-x 3 bartek bartek   4096 10-19 00:11 session_dfab3011
# drwxr-xr-x 3 bartek bartek   4096 10-19 00:10 session_a0b48539
# drwxr-xr-x 3 bartek bartek   4096 10-18 23:57 session_8a2d0381
# drwxr-xr-x 3 bartek bartek   4096 10-18 20:02 session_75b687ba
# drwxr-xr-x 3 bartek bartek   4096 10-18 18:07 session_791d17ed
# drwxr-xr-x 3 bartek bartek   4096 10-18 18:07 session_05e444a2
# drwxr-xr-x 3 bartek bartek   4096 10-18 18:06 session_4aa4046e
# -rw-r--r-- 1 bartek bartek   3137 10-18 17:48 argparse_pokemon.py
# -rw-r--r-- 1 bartek bartek   3073 10-17 18:56 tile_vids_to_grid.py
# drwxr-xr-x 2 bartek bartek   4096 10-17 18:56 session_e1b6d2dc_post_train_more_steps
# drwxr-xr-x 2 bartek bartek   4096 10-17 18:56 session_bfdca25a
# drwxr-xr-x 2 bartek bartek   4096 10-17 18:56 session_b30478f4
# drwxr-xr-x 2 bartek bartek   4096 10-17 18:56 ray_exp
# -rw-r--r-- 1 bartek bartek   3056 10-17 18:56 render_all_needed_grids.py
# -rwxr-xr-x 1 bartek bartek     83 10-17 18:56 render_all_needed_grids.sh
# -rw-r--r-- 1 bartek bartek   1712 10-17 18:56 requirements.txt
# -rw-r--r-- 1 bartek bartek    203 10-17 18:56 requirements-unfrozen.txt
# -rw-r--r-- 1 bartek bartek   1675 10-17 18:56 run_baseline.py
# -rw-r--r-- 1 bartek bartek   2835 10-17 18:56 run_pretrained_interactive.py
# -rw-r--r-- 1 bartek bartek   1391 10-17 18:56 run_recorded_actions.py
# -rw-r--r-- 1 bartek bartek   2580 10-17 18:56 saves_to_record.txt
# drwxr-xr-x 2 bartek bartek   4096 10-17 18:56 session_4da05e87_main_good
# drwxr-xr-x 2 bartek bartek   4096 10-17 18:56 grinds_to_level_11_extra_time_14
# -rw-r--r-- 1 bartek bartek     53 10-17 18:56 delete_empty_imgs.txt
# drwxr-xr-x 3 bartek bartek   4096 10-17 18:56 grid_renders
# -rw-r--r-- 1 bartek bartek      4 10-17 18:56 agent_enabled.txt
# drwxr-xr-x 2 bartek bartek   4096 10-17 18:56 best_12-7

# %%
session_path = 'baselines/session_5db1f749'

# %%
def load_run_data(run_path):
    run_lists = []
    for p in Path(run_path).glob('all_runs_*.json'):
        with open(p, 'r') as f:
            run_lists.append(json.load(f))
    all_runs = [val for tup in zip(*run_lists) for val in tup]
    print(f'runs loaded: {len(all_runs)}')
    return all_runs

# %%
def plot_runs(
    all_runs, use_keys=None, 
    plot_fit=False, plot_line=False, 
    start=0, group_runs=1,
    agg_func=np.mean):
    
    all_runs = all_runs[start:]
    x = np.arange(len(all_runs)//group_runs)
    
    def add_plot(y, name, alpha, size, plot_line, plot_fit):
        plt.scatter(x, y, alpha=alpha, s=size, label=name)
        if plot_line:
            plt.plot(x, y, alpha=alpha, label=name)
        if plot_fit:
            regr = linear_model.LinearRegression()
            # Optimize linear model
            regr.fit(x.reshape(-1, 1), y.reshape(-1, 1))

            # Make predictions using the testing set
            lin_y = regr.predict(x.reshape(-1, 1))
            plt.plot(x, lin_y, linewidth=3)
    
    # convert list of dictionaries to dictionary of lists
    metrics = {m: [run[m] for run in all_runs] for m in all_runs[0].keys()}
    metrics['total'] = [sum([v for _,v in run.items()]) for run in all_runs]
    if group_runs:
        for m, dat in metrics.items():
            metrics[m] = agg_func(np.array(dat).reshape(-1, group_runs), 1)
    available_keys = metrics.keys()
    print(f'available metrics: {list(available_keys)}')
    if use_keys is None:
        use_keys = available_keys
    
    ## TODO subplot for each metric ## 
    NUM_COLORS = len(use_keys)
    cm = plt.get_cmap('Dark2')
    cNorm  = colors.Normalize(vmin=0, vmax=NUM_COLORS-1)
    scalarMap = mplcm.ScalarMappable(norm=cNorm, cmap=cm)
    fig = plt.figure(figsize = (12, 8))

    ax = fig.add_subplot(111)
    ax.set_prop_cycle(color=[scalarMap.to_rgba(i) for i in range(NUM_COLORS)])

    for i, m in enumerate(use_keys):
        add_plot(
            np.array(metrics[m]), m, 1.0, 3.0, plot_line, plot_fit
        )

    plt.title('Reward over runs PPO')
    plt.legend(bbox_to_anchor=(1.04, 0.5), loc="center left", borderaxespad=0)
    plt.show()

# %%
def get_latest_grid(pth):
    imgs = np.array([np.array(Image.open(p)) for p in Path(pth).glob('curframe*.jpeg')])
    grid = rearrange(imgs, '(h2 w2) h w c -> (h2 h) (w2 w) c', w2=4)
    return grid

# %%
'''
get_im_func = lambda: get_latest_grid('baselines/session_d34118d3')

with media.VideoWriter('test_grid.mp4', get_im_func().shape[:2]) as wr:
    for i in range(500):
        #wr.add_image(get_im_func())
        #time.sleep(1)
'''
# Out:
# "\nget_im_func = lambda: get_latest_grid('baselines/session_d34118d3')\n\nwith media.VideoWriter('test_grid.mp4', get_im_func().shape[:2]) as wr:\n    for i in range(500):\n        #wr.add_image(get_im_func())\n        #time.sleep(1)\n"

# %%
plt.figure(figsize = (4, 1))
plt.imshow(get_latest_grid(session_path))

# %%
(29556736 - 25952256) / (1024*16*44)

# %%
plot_runs(
    load_run_data(session_path),
    use_keys=None,
    plot_line=False,
    plot_fit=False,
    start=0,
    group_runs=1,
    agg_func=np.mean
)
# Out:
# runs loaded: 272
# available metrics: ['event', 'level', 'heal', 'op_lvl', 'dead', 'badge', 'explore', 'steps', 'total']

# %% [markdown]
# ## generate moving histograms!

# %%
len(load_run_data('baselines/session_4da05e87_main_full'))
# Out:
# runs loaded: 26840
# 26840

# %%
def chunks(data, n):
    n = max(1, n)
    return [data[i:i+n] for i in range(0, len(data), n)]

# %%
full_dat = load_run_data('baselines/session_4da05e87_main_full')
for run in full_dat:
    run["total"] = sum(value for value in run.values())
full_dat_chunks = chunks(full_dat, 44)
# Out:
# runs loaded: 26840

# %%
full_dat[0]
# Out:
# {'event': 0,
#  'level': 2,
#  'heal': 0.7431809773652174,
#  'op_lvl': 0.0,
#  'dead': -0.30000000000000004,
#  'badge': 0,
#  'explore': 1.488,
#  'total': 3.931180977365217}

# %%
def histo_plot(axis, stat, dat_chunks, version, compare_count):
    
    test_dat = np.array([run[stat] for run in dat_chunks[version]])
    # the histogram of the data
    n, bins, patches = axis.hist(test_dat, 10, density=False, facecolor="orange", alpha=0.95)
    
    for i in range(compare_count):
        comp_version = max(version - 1 - i, 0)
        compare_dat = np.array([run[stat] for run in dat_chunks[comp_version]])
        n, bins, patches = axis.hist(compare_dat, 10, density=False, facecolor="grey", alpha=0.2*0.25**i)

    axis.set(xlabel=f"{stat}")
    #axis.ylabel()
    # only use this title over all plots
    #axis.title()
    #plt.xlim(40, 160)
    #plt.ylim(0, 0.03)
    #axis.grid(True)
    #plt.show()

# %%
def plot_all(dat_chunks, version, compare_count):
    fig, axs = plt.subplots(2, 4, figsize=(16, 9), dpi=120)
    #plt.subplots_adjust(bottom=0.0, right=0.8, top=0.9)
    fig.suptitle(f"Version {version} Rewards")
    for stat, ax in zip(dat_chunks[0][0].keys(), axs.flatten()):
        histo_plot(ax, stat, dat_chunks, version, compare_count)
    return fig

# %%
plot_all(chunks(full_dat, 44), 10, 5)

# %%
#histo_plot("level", )

# %%
with media.VideoWriter('histograms_over_time.mp4', (1080, 1920)) as wr:
    for i in tqdm(range(610)):
        #with plt.style.context('Solarize_Light2'):
        fig = plot_all(full_dat_chunks, i, 5)

        fig.canvas.draw()
        #plt.show()
        data = np.frombuffer(fig.canvas.tostring_rgb(), dtype=np.uint8)
        data = data.reshape(fig.canvas.get_width_height()[::-1] + (3,))
        wr.add_image(data)
        plt.close()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [219], in <cell line: 1>()
#       1 with media.VideoWriter('histograms_over_time.mp4', (1080, 1920)) as wr:
# ----> 2     for i in tqdm(range(610)):
#       3         #with plt.style.context('Solarize_Light2'):
#       4         fig = plot_all(full_dat_chunks, i, 5)
#       6         fig.canvas.draw()
#
# TypeError: 'module' object is not callable
